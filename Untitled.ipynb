# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.genfromtxt('sample_data.txt')

# %%
plt.plot(data[:,2], data[:,0])
plt.show()

# %%
data[2,:]
# Out:
# array([  9.43000000e+02,   6.10000000e+02,  -1.80000000e+01,
#         -2.25000000e+01,   6.80000000e+01,   6.70000000e-01,
#          3.15000000e+02,   1.70000000e+01,   2.59500000e+02,
#          2.61400000e+02,   2.59600000e+02])
